# %% [markdown]
# ## # Introduction
# <p><img src="https://i.imgur.com/kjWF1So.jpg" alt="Different characters on a computer screen"></p>
# <p>According to a 2019 <a href="https://storage.googleapis.com/gweb-uniblog-publish-prod/documents/PasswordCheckup-HarrisPoll-InfographicFINAL.pdf">Google / Harris Poll</a>, 24% of Americans have used common passwords, like <code>abc123</code>, <code>Password</code>, and <code>Admin</code>. Even more concerning, 59% of Americans have incorporated personal information, such as their name or birthday, into their password. This makes it unsurprising that 4 in 10 Americans have had their personal information compromised online. Passwords with commonly used phrases and personal information makes cracking a password drastically easier.</p>
# <p>You may have noticed over the years that password requirements have increased in complexity, including recommendations to change your passwords every couple of months. Compiled from industry recommendations, below is a list of passwords requirements you will be asked to test: </p>
# <p><strong>Password Requirments:</strong></p>
# <ol>
# <li>Must be at least 10 characters in length</li>
# <li>Must contain at least:<ul>
# <li>one lower case letter </li>
# <li>one upper case letter </li>
# <li>one numeric character </li>
# <li>one non-alphanumeric character</li></ul></li>
# <li>Must not contain the phrase <code>password</code> (case insensitive)</li>
# <li>Must not contain the user's first or last name, e.g., if the user's name is <code>John Smith</code>, then <code>SmItH876!</code> is not a valid password.</li>
# </ol>
# <p>Here is the dataset that you will investigate this project:</p>
# <div style="background-color: #ebf4f7; color: #595959; text-align:left; vertical-align: middle; padding: 15px 25px 15px 25px; line-height: 1.6;">
#     <div style="font-size:20px"><b>datasets/logins.csv</b></div>
# Each row represents a login credential. There are no missing values and you can consider the dataset "clean".
# <ul>
#     <li><b>id:</b> the user's unique ID.</li>
#     <li><b>username:</b> the username with the format {firstname}.{lastname}.</li>
#     <li><b>password:</b> the password that may or may not meet the requirements. <i>Note, passwords should never be saved in plaintext, always encrypt them when working with real live passwords!</i></li>
# </ul>
# </div>
# <p>Warning: This dataset contains some <strong>real</strong> passwords leaked from <strong>real</strong> websites. These passwords have been filtered, but may still include words that are explicit and offensive.</p>
# <p>From here on out, it will be your task to explore and manipulate the existing data until you can answer the two questions described in the instructions panel. Feel free to import as many packages as you need to complete your task, and add cells as necessary. Finally, remember that you are only tested on your answer, not on the methods you use to arrive at the answer!</p>
# <p><strong>Note:</strong> To complete this project, you need to know how to manipulate strings in pandas DataFrames and be familiar with regular expressions. Before starting this project we recommend that you have completed the following courses: <a href="https://learn.datacamp.com/courses/data-cleaning-in-python">Data Cleaning in Python</a> and <a href="https://learn.datacamp.com/courses/regular-expressions-in-python">Regular Expressions in Python</a>.</p>

# %%
#Importovanje podataka

import pandas as pd
import re

df=pd.read_csv('datasets/logins.csv')
df.head()
username=df['username'].str.split('.',expand=True)
username.columns=[['ime','prezime']]
df['ime']=username['ime']
df['prezime']=username['prezime']
df.head()
# Out:
#    id         username               password       ime   prezime
# 0   1   vance.jennings         vanceRules888!     vance  jennings
# 1   2   consuelo.eaton  Mail_Pen%Scarlets.414  consuelo     eaton
# 2   3  mitchel.perkins               Z00+1960   mitchel   perkins
# 3   4   odessa.vaughan              D-rockyou    odessa   vaughan
# 4   5   araceli.wilder             Araceli}r3   araceli    wilder

# %%
#Izracunavanje procenta korisnika sa losim siframa
m=0
v=0
b=0
z=0
d=0
s=0

i=0
lista=list()

while i<len(df):
    if len(df.iloc[i,2])<10:
        d+=1
    elif not re.search('[A-Z]',df.iloc[i,2]):
        v+=1
    elif not re.search('[a-z]',df.iloc[i,2]):
        m+=1
    elif not re.search('[0-9]',df.iloc[i,2]):
        b+=1
    elif (df.iloc[i,2].isalnum()==True):
        z+=1
    elif re.search('password',df.iloc[i,2]):
        s+=1
    if(d==1 or v==1 or m==1 or b==1 or z==1 or s==1):
        lista.append(df.iloc[i,1])

    m=0
    v=0
    b=0
    z=0
    d=0
    s=0

    i+=1

for i, row in df.iterrows():
    if row.ime in row.password.lower() or row.prezime in row.password.lower():
        lista.append(row.username)

# %%
bad_pass=round(float(len(lista)/len(df)),2)
bad_pass
# Out:
# 0.76

# %%
#Lista korisnika koji trebaju da promene sifru

lista.sort()
lista
# Out:
# ['abdul.rowland',
#  'addie.cherry',
#  'adele.moreno',
#  'adeline.bush',
#  'adolfo.kane',
#  'adolfo.lara',
#  'ahmad.hopper',
#  'aida.combs',
#  'aisha.jenkins',
#  'al.dunlap',
#  'alana.franco',
#  'alberta.leblanc',
#  'alec.robbins',
#  'alejandra.stephenson',
#  'alejandro.burke',
#  'alejandro.nieves',
#  'alexander.thomas',
#  'alexandria.hinton',
#  'alexis.mccullough',
#  'alexis.reynolds',
#  'alfonso.weaver',
#  'alfonzo.johns',
#  'alisa.campbell',
#  'alisa.cohen',
#  'alison.neal',
#  'allan.marshall',
#  'alonzo.fowler',
#  'amado.bridges',
#  'amado.fitzgerald',
#  'amber.summers',
#  'amber.vega',
#  'amelia.frost',
#  'amie.blanchard',
#  'amos.maldonado',
#  'amparo.evans',
#  'anastasia.fry',
#  'anderson.black',
#  'anderson.dillard',
#  'andre.serrano',
#  'andrea.berg',
#  'andrea.day',
#  'andy.cruz',
#  'angel.jefferson',
#  'angelina.gaines',
#  'angelita.white',
#  'angelita.york',
#  'anibal.rivas',
#  'anna.pugh',
#  'annette.maynard',
#  'annette.terrell',
#  'antoine.johnson',
#  'anton.pruitt',
#  'antonia.stephenson',
#  'araceli.wilder',
#  'ariel.mendez',
#  'armand.martinez',
#  'art.velez',
#  'ashley.house',
#  'ashley.shaw',
#  'aurelia.blair',
#  'aurelia.langley',
#  'autumn.alford',
#  'barbra.puckett',
#  'beatrice.hall',
#  'beatrice.sparks',
#  'beatriz.ward',
#  'beau.armstrong',
#  'becky.hickman',
#  'benita.schneider',
#  'benito.le',
#  'bernadine.whitfield',
#  'bernardo.fernandez',
#  'berry.mcneil',
#  'bertie.yang',
#  'betsy.oneal',
#  'billie.fowler',
#  'blake.harrell',
#  'bobbie.rollins',
#  'bonita.ingram',
#  'bonita.morin',
#  'brain.webster',
#  'brandi.brooks',
#  'brandon.francis',
#  'brant.zimmerman',
#  'brenda.blevins',
#  'brenda.crawford',
#  'brendan.barron',
#  'brent.hebert',
#  'brittany.mosley',
#  'brooke.ferrell',
#  'bruno.acosta',
#  'bryan.fisher',
#  'bryant.briggs',
#  'bryon.pratt',
#  'burl.parrish',
#  'burl.perkins',
#  'byron.cooley',
#  'byron.dominguez',
#  'byron.jacobs',
#  'caleb.powers',
#  'candice.bolton',
#  'carl.morton',
#  'carlene.young',
#  'carlo.dunlap',
#  'carmela.clayton',
#  'carmelo.byers',
#  'carmelo.sherman',
#  'carol.campos',
#  'carroll.whitfield',
#  'cary.schneider',
#  'cathryn.roberts',
#  'celeste.cox',
#  'chadwick.day',
#  'charles.ayala',
#  'charles.morris',
#  'charley.fuller',
#  'charley.key',
#  'chase.garza',
#  'chase.trujillo',
#  'chasity.whitfield',
#  'cheri.ryan',
#  'chris.sanford',
#  'christa.adkins',
#  'christa.morrison',
#  'christie.watson',
#  'christine.mcconnell',
#  'christoper.clark',
#  'christy.hensley',
#  'christy.lindsey',
#  'chrystal.burns',
#  'clair.richmond',
#  'claire.jefferson',
#  'clara.ward',
#  'clarence.britt',
#  'clarissa.powers',
#  'clayton.holloway',
#  'cleo.durham',
#  'clifford.steele',
#  'clifton.norton',
#  'clinton.marsh',
#  'collin.dixon',
#  'concepcion.case',
#  'consuelo.gibbs',
#  'cornelia.greer',
#  'cornelius.rutledge',
#  'courtney.conner',
#  'crystal.adams',
#  'cynthia.browning',
#  'daisy.gill',
#  'daisy.lopez',
#  'daisy.washington',
#  'damian.savage',
#  'dannie.gaines',
#  'dannie.mcguire',
#  'dannie.olsen',
#  'daren.guthrie',
#  'daren.strong',
#  'darius.alvarez',
#  'darius.norton',
#  'darla.wall',
#  'dean.carter',
#  'deanna.giles',
#  'dee.mccoy',
#  'deidre.brooks',
#  'della.landry',
#  'della.petty',
#  'delmer.lynn',
#  'deloris.dixon',
#  'dena.pollard',
#  'denis.stone',
#  'denny.harrell',
#  'derick.day',
#  'devon.burgess',
#  'devon.harrington',
#  'devon.holman',
#  'dewayne.drake',
#  'dewey.bonner',
#  'diann.nicholson',
#  'dianna.munoz',
#  'dianna.munoz',
#  'diego.elliott',
#  'dirk.frazier',
#  'dixie.noble',
#  'dolly.bonner',
#  'dolores.terry',
#  'domingo.dyer',
#  'dominique.cherry',
#  'dominique.joyner',
#  'donna.calhoun',
#  'donna.mcmahon',
#  'donnie.hodges',
#  'dorian.caldwell',
#  'doris.higgins',
#  'dorothea.klein',
#  'doug.dickerson',
#  'doyle.hess',
#  'drew.johns',
#  'drew.roach',
#  'duane.cooley',
#  'dudley.koch',
#  'dwayne.benton',
#  'dwayne.hurst',
#  'earlene.cooper',
#  'earline.obrien',
#  'ebony.donaldson',
#  'edgar.odom',
#  'edmund.dunn',
#  'edward.bryan',
#  'edward.lynch',
#  'edwardo.goff',
#  'efrain.long',
#  'elba.morton',
#  'elias.holland',
#  'elias.short',
#  'elise.newman',
#  'elizabeth.potter',
#  'elma.campos',
#  'elmer.mccormick',
#  'eloise.chapman',
#  'eloise.newman',
#  'emerson.caldwell',
#  'emily.wise',
#  'emma.douglas',
#  'enrique.mendoza',
#  'eric.buckner',
#  'erick.miles',
#  'erma.warren',
#  'erna.horton',
#  'ervin.dyer',
#  'esmeralda.irwin',
#  'estella.david',
#  'estella.ortega',
#  'estelle.sexton',
#  'estelle.sexton',
#  'esther.lang',
#  'eugene.mckenzie',
#  'eugenio.bray',
#  'evangelina.barton',
#  'eve.gamble',
#  'eve.oconnor',
#  'everett.hale',
#  'ezra.aguilar',
#  'faye.johns',
#  'felicia.joyce',
#  'fletcher.dillon',
#  'florence.jimenez',
#  'florine.gibson',
#  'flossie.klein',
#  'foster.james',
#  'francine.buckner',
#  'francisca.hill',
#  'francisco.logan',
#  'frank.bean',
#  'frankie.allen',
#  'frankie.head',
#  'franklin.jordan',
#  'fredrick.stafford',
#  'freeman.rose',
#  'freida.brown',
#  'freida.greene',
#  'gabriela.fisher',
#  'gabrielle.reid',
#  'gale.barron',
#  'gale.burnett',
#  'garland.perkins',
#  'garth.turner',
#  'gena.osborn',
#  'genaro.russo',
#  'geoffrey.kidd',
#  'gerardo.mcmahon',
#  'gilbert.sykes',
#  'giovanni.beard',
#  'glen.guerra',
#  'glen.rivers',
#  'glenn.deleon',
#  'glenn.mcdonald',
#  'glenna.tanner',
#  'gloria.davis',
#  'goldie.puckett',
#  'greg.schultz',
#  'gregory.houston',
#  'greta.english',
#  'gus.macdonald',
#  'gus.padilla',
#  'gustavo.kirkland',
#  'gwendolyn.spears',
#  'gwendolyn.tate',
#  'hallie.melendez',
#  'harley.campos',
#  'harley.martin',
#  'harriett.herring',
#  'harrison.cooley',
#  'harry.collier',
#  'heather.francis',
#  'helene.cortez',
#  'henry.kelley',
#  'heriberto.hatfield',
#  'herman.shepherd',
#  'herschel.fernandez',
#  'herschel.graves',
#  'hester.collins',
#  'hiram.frost',
#  'homer.emerson',
#  'hope.hayden',
#  'horace.guerra',
#  'horace.sherman',
#  'houston.garcia',
#  'howard.estrada',
#  'imogene.oneil',
#  'ira.cortez',
#  'irene.jarvis',
#  'iris.chandler',
#  'iris.morton',
#  'irma.vasquez',
#  'irvin.martinez',
#  'irving.franks',
#  'jackie.ayala',
#  'jackie.burris',
#  'jacob.boone',
#  'jacob.chaney',
#  'jacqueline.adams',
#  'jacqueline.jennings',
#  'jacquelyn.brady',
#  'jaime.fulton',
#  'jamal.fry',
#  'jamel.good',
#  'jamie.goodman',
#  'jan.silva',
#  'janet.kirk',
#  'janette.rodriquez',
#  'janie.acosta',
#  'jannie.solomon',
#  'jarred.white',
#  'jarrett.marsh',
#  'jasmine.meadows',
#  'jasper.andrews',
#  'jeannie.brewer',
#  'jenifer.beck',
#  'jenna.vaughan',
#  'jennifer.hewitt',
#  'jennifer.sanders',
#  'jenny.woodard',
#  'jerald.melendez',
#  'jerome.mcfadden',
#  'jerrold.rodriquez',
#  'jerrold.summers',
#  'jerry.cash',
#  'jewel.dennis',
#  'jimmy.wade',
#  'joann.atkinson',
#  'joaquin.walters',
#  'jocelyn.gonzalez',
#  'jodie.velazquez',
#  'jody.petty',
#  'joey.poole',
#  'johanna.melton',
#  'john.battle',
#  'john.murray',
#  'johnnie.lester',
#  'johnnie.sweet',
#  'jolene.henry',
#  'jolene.reid',
#  'jonah.atkins',
#  'jonas.bowen',
#  'josephine.burton',
#  'joshua.blair',
#  'juan.doyle',
#  'judson.emerson',
#  'julia.savage',
#  'julian.gross',
#  'julie.lloyd',
#  'juliette.rios',
#  'junior.hewitt',
#  'kareem.hogan',
#  'kareem.trevino',
#  'karina.morton',
#  'kathrine.carpenter',
#  'katie.gonzalez',
#  'katie.gross',
#  'kelley.barrett',
#  'kenneth.kennedy',
#  'kenny.franco',
#  'kerry.klein',
#  'kieth.barron',
#  'kimberly.lawson',
#  'kimberly.lawson',
#  'kirk.english',
#  'kris.hatfield',
#  'kristi.jordan',
#  'kristopher.jimenez',
#  'kyle.colon',
#  'kyle.colon',
#  'lacey.perry',
#  'lakeisha.frazier',
#  'landon.lloyd',
#  'lane.mccarty',
#  'lara.bright',
#  'lara.chavez',
#  'latisha.nicholson',
#  'latonya.briggs',
#  'laurel.strickland',
#  'lauri.huffman',
#  'lavern.grimes',
#  'lavonne.dunlap',
#  'lavonne.pacheco',
#  'lea.sharp',
#  'leah.perry',
#  'leanna.abbott',
#  'lee.hendricks',
#  'lee.roman',
#  'leland.morrison',
#  'lena.mckay',
#  'leola.waller',
#  'leonor.padilla',
#  'leroy.montoya',
#  'les.cote',
#  'lesa.battle',
#  'leslie.finley',
#  'leslie.foreman',
#  'lester.william',
#  'lilian.gordon',
#  'liliana.robertson',
#  'lilly.lee',
#  'lindsey.knowles',
#  'lindsey.pitts',
#  'linwood.marshall',
#  'liz.langley',
#  'liz.mcbride',
#  'liz.mcbride',
#  'lizzie.lawrence',
#  'lloyd.jacobs',
#  'lonnie.oneal',
#  'lora.quinn',
#  'loren.crosby',
#  'loretta.bass',
#  'loretta.bass',
#  'loretta.dickson',
#  'lorie.mccoy',
#  'lorna.walton',
#  'louella.bolton',
#  'louis.mcbride',
#  'lucien.valdez',
#  'lucille.barker',
#  'lucille.stark',
#  'lucinda.wiley',
#  'lucio.shields',
#  'luisa.riley',
#  'lula.sherman',
#  'luther.sweet',
#  'lynn.cross',
#  'lynne.knowles',
#  'mable.delgado',
#  'mable.nixon',
#  'mac.franco',
#  'maggie.bishop',
#  'maggie.contreras',
#  'maggie.willis',
#  'mai.odom',
#  'mai.valdez',
#  'major.daniels',
#  'malinda.avila',
#  'malinda.bright',
#  'mamie.fox',
#  'mandy.mosley',
#  'manuel.santos',
#  'marcelino.mcmahon',
#  'marcia.pitts',
#  'marcie.campbell',
#  'marcie.frost',
#  'margaret.garrison',
#  'margarito.gates',
#  'margie.zimmerman',
#  'margret.hogan',
#  'marguerite.hunter',
#  'mariano.alston',
#  'maribel.rich',
#  'marisol.porter',
#  'maritza.williams',
#  'marjorie.haynes',
#  'mark.bond',
#  'marla.jimenez',
#  'marlene.faulkner',
#  'marlin.alford',
#  'marlin.fleming',
#  'martha.pennington',
#  'martin.foley',
#  'martin.pacheco',
#  'maryanne.moran',
#  'mason.hutchinson',
#  'mathew.cummings',
#  'mathew.wiley',
#  'matt.snow',
#  'mattie.burris',
#  'maureen.gross',
#  'maureen.patton',
#  'maureen.roth',
#  'maurice.gay',
#  'maxwell.macias',
#  'meagan.stone',
#  'melanie.jordan',
#  'melody.chase',
#  'merlin.vance',
#  'mia.allen',
#  'michele.ward',
#  'miguel.moody',
#  'mike.baxter',
#  'mildred.hammond',
#  'miles.gates',
#  'milford.hubbard',
#  'millard.curry',
#  'millard.justice',
#  'millicent.holcomb',
#  'mindy.clarke',
#  'minnie.bruce',
#  'mitch.ferguson',
#  'mitchel.perkins',
#  'mohammad.kerr',
#  'mona.frederick',
#  'monica.flores',
#  'monique.hodges',
#  'monty.golden',
#  'morgan.kirkland',
#  'morris.price',
#  'morton.pearson',
#  'muriel.potts',
#  'myrna.fleming',
#  'myron.hawkins',
#  'nanette.humphrey',
#  'napoleon.gonzalez',
#  'natalia.mejia',
#  'nathan.dillard',
#  'nathaniel.dotson',
#  'nathaniel.robinson',
#  'ned.santana',
#  'ned.stein',
#  'neil.phillips',
#  'neva.conway',
#  'newton.hooper',
#  'nicholas.watts',
#  'nicole.brooks',
#  'nicole.leach',
#  'noelle.tucker',
#  'noreen.hale',
#  'norma.barnes',
#  'norma.koch',
#  'norman.riggs',
#  'normand.mckinney',
#  'norris.morales',
#  'norris.small',
#  'numbers.cline',
#  'odessa.vaughan',
#  'ollie.dunlap',
#  'omar.carver',
#  'ora.stuart',
#  'orlando.summers',
#  'oscar.winters',
#  'paige.monroe',
#  'pat.warren',
#  'patrica.sampson',
#  'patrice.burgess',
#  'patsy.jennings',
#  'patti.dixon',
#  'patty.marks',
#  'patty.riggs',
#  'paula.cotton',
#  'paula.gonzales',
#  'pedro.wolfe',
#  'penny.conway',
#  'petra.abbott',
#  'petra.wiggins',
#  'phyllis.wells',
#  'porfirio.hooper',
#  'queen.monroe',
#  'quincy.hart',
#  'ramona.ryan',
#  'randell.burgess',
#  'raphael.sykes',
#  'raul.morton',
#  'raymond.woodard',
#  'raymundo.haley',
#  'regina.guthrie',
#  'regina.levy',
#  'reginald.randall',
#  'rene.nixon',
#  'reuben.higgins',
#  'reuben.wells',
#  'reyes.levine',
#  'reyna.holloway',
#  'reyna.tran',
#  'rhoda.mayo',
#  'rick.mcclure',
#  'rico.valentine',
#  'rigoberto.cleveland',
#  'rob.hopper',
#  'rob.rush',
#  'robby.reese',
#  'robby.schmidt',
#  'robert.cooley',
#  'rocco.kirkland',
#  'roderick.riddle',
#  'rodney.gilbert',
#  'rodolfo.william',
#  'rogelio.payne',
#  'roger.golden',
#  'roland.mcgee',
#  'roland.whitaker',
#  'rolland.wagner',
#  'roman.tanner',
#  'romeo.gibson',
#  'ronald.brooks',
#  'rory.parsons',
#  'rosalie.middleton',
#  'rosalind.kelley',
#  'rosalinda.rodriquez',
#  'rosario.bernard',
#  'rosario.larsen',
#  'rosario.merrill',
#  'rosella.barrett',
#  'roslyn.bartlett',
#  'ross.sutton',
#  'royce.combs',
#  'ruben.huff',
#  'russ.morales',
#  'russel.mcclain',
#  'sabrina.suarez',
#  'salvador.osborn',
#  'sammie.montgomery',
#  'sanford.holman',
#  'santiago.mcmillan',
#  'sarah.wiggins',
#  'saul.meyers',
#  'saundra.king',
#  'saundra.king',
#  'savannah.leonard',
#  'scot.golden',
#  'scotty.shannon',
#  'sean.leon',
#  'sebastian.jackson',
#  'serena.price',
#  'sergio.puckett',
#  'seymour.randolph',
#  'shana.tyler',
#  'shane.rivera',
#  'shane.watkins',
#  'shari.bruce',
#  'sharon.hodges',
#  'sharron.bryant',
#  'sharron.pittman',
#  'shawn.harrington',
#  'shawn.morse',
#  'sheila.brown',
#  'shelby.bond',
#  'shelby.massey',
#  'shelby.peck',
#  'sherrie.norman',
#  'sheryl.wynn',
#  'sidney.walker',
#  'silvia.duke',
#  'silvia.franco',
#  'simon.miranda',
#  'solomon.baldwin',
#  'sondra.lowe',
#  'staci.castaneda',
#  'staci.pugh',
#  'stacy.hess',
#  'stan.lamb',
#  'stanley.workman',
#  'stefan.irwin',
#  'stefan.shaffer',
#  'stefan.wheeler',
#  'stella.hicks',
#  'steve.brady',
#  'susan.houston',
#  'susie.vega',
#  'suzanne.gallegos',
#  'suzanne.nash',
#  'suzette.hatfield',
#  'sylvester.owens',
#  'tabatha.boyle',
#  'tabatha.mckay',
#  'tabitha.ashley',
#  'tammie.ayers',
#  'tammie.hanson',
#  'tania.norman',
#  'tania.ochoa',
#  'tanisha.ortega',
#  'tanya.brown',
#  'tara.mckenzie',
#  'taylor.kramer',
#  'ted.horne',
#  'teresa.bentley',
#  'terra.hogan',
#  'terrence.nieves',
#  'terry.hayes',
#  'thelma.small',
#  'theresa.sweet',
#  'thurman.osborne',
#  'tiffany.sanders',
#  'tod.hyde',
#  'todd.soto',
#  'tom.gallegos',
#  'tomas.gallegos',
#  'tommie.ferrell',
#  'tonia.patton',
#  'tracie.wilcox',
#  'trenton.boyle',
#  'tricia.frost',
#  'trinidad.austin',
#  'trinidad.rodriquez',
#  'trudy.le',
#  'twila.fuller',
#  'ulysses.patterson',
#  'ursula.wood',
#  'valentin.castillo',
#  'valeria.curry',
#  'vance.jennings',
#  'vanessa.davis',
#  'verna.white',
#  'vicente.hopper',
#  'victor.bryan',
#  'vilma.hart',
#  'vincent.contreras',
#  'viola.foster',
#  'violet.horn',
#  'virgie.atkins',
#  'walter.blackwell',
#  'walter.conner',
#  'walter.hughes',
#  'wilburn.shepherd',
#  'wilford.kaufman',
#  'wilfredo.keller',
#  'willard.williamson',
#  'williams.mcfarland',
#  'williams.rios',
#  'willis.cervantes',
#  'wyatt.finley',
#  'young.booth',
#  'yvette.whitfield',
#  'yvonne.munoz',
#  'zachary.huff',
#  'zelma.abbott',
#  'zelma.rosario']
